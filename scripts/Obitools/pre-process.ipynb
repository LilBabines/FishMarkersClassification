# %%
import pandas as pd

# %%
for fold in range(6):
    
    df = pd.read_csv(f"./data/teleo/fold_{fold+1}/train.csv")
    no_sythetic = df[df["species"]!="Synthetic"]
    no_sythetic.to_csv(f"./data/teleo/fold_{fold+1}/train_pure.csv", index=False)
